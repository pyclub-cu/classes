# %% [markdown]
# <a href="https://colab.research.google.com/github/pyclub-cu/classes/blob/master/Week_3_Objects_numbers%2C_strings_and_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3
# # **Objects: numbers, strings and lists**
#
# ## **Learning Goals**
# * Learn about different types of objects (10 mins)
# * Learn how to assign variables (10 mins)
# * Do some math calculations! (15 mins)
# * Make and use lists (15 mins)
#
# ## **Icebreaker!**
# ![icebreakergraphic_small.png](data:image/png;base64,...)
#
# Question: Name as many creatures (or things) of the sea as you can! Later, we can try to categorise them into lists!
#
# Example: Sea urchins, jellyfish and plastic bottles!

# %% [markdown]
# # **Objects**
#
# Most things in Python are objects, such as this list of prime numbers:
# ```
# prime_numbers = [2,3,5,7,11,13]
# ```
# Even the numbers in `prime_numbers` are objects.
#
# Now, here's my grocery list 🛒:
# ```
# groceries = ['apples','yams','bread','eggs','sour patch kids']
# ```
#
# Both `prime_numbers` and `groceries` are lists, but they are different in one major way. **What do you think that is?**

# %% [markdown]
# ## Types of objects
# In this class we are going to focus on two types of objects that we will use a lot: **numbers** and **strings**
#
# ![numbersORstrings.png](data:image/png;base64,...)

# %% [markdown]
# ### Numbers: integers and floats
#
# Python understands two types of numbers: integers and floats.
#
# * `7` is an integer
# > an integer is a whole number without a decimal place
# * `7.0` is a float
# > a float is a number with a decimal place

# %% [markdown]
# **How many integers are there in this list?**
#
# list = [0, 5, 3.0, 6.6, 550, 10]

# %%
# enter your answer below
# Out:
# 5

# %% [markdown]
# **Which of the numbers below is a float?**
#
# 0, 243, 6, 70, 4.2, 99

# %%
# enter your answer below
# Out:
# 4.2

# %% [markdown]
# You can also turn an integer into a float with the `float()` command:

# %%
float(9)
# Out:
# 9.0

# %% [markdown]
# **Try it yourself!**

# %% [markdown]
# ### Strings
#
# In Python, "strings" are made up of characters, words and sentences

# %%
'a' # this is a string
# Out:
# 'a'

# %%
'this is a string too'
# Out:
# 'this is a string too'

# %% [markdown]
# **Practice making some of your own strings below!**

# %% [markdown]
# ## Assigning Variables
# So far, we're able to type integers, decimals and words into `code cells` when and as we want.
#
# If we want to save the numbers or words for later use, we need to **assign** them to variables.
#
# **What are variables?**
# > Variables are where we can store objects in our code. We can assign different types of objects (floats, integers and strings) to variables
#
# Here is an example of assigning a variable to a number:

# %%
my_age = 77

# %% [markdown]
# Here is an example of assigning a variable to a string:

# %%
my_name = 'Suki'

# %% [markdown]
# Now, let's go ahead and delete the above cell! (To delete, click the above code cell, and click on the trash-can icon)
#
# Despite deleting the cell, my name was stored under the variable name, `my_name`. In other words, Python has remembered my name, try testing this out by printing `my_name`

# %%
# enter below

# %%
# print Suki's age below

# %% [markdown]
# It is possible to assign multiple variables at once:

# %%
street, avenue = 116, 'Amsterdam'
print(street)
print(avenue)
# Out:
# 116
# Amsterdam

# %% [markdown]
# ## Mathematical operations
# Python can do maths, much like a calculator
#
# * to add you use `+`
# * to subtract you use `-`
# * to multiply you use `*`
# * brackets can be used to infer the order of operations

# %%
# Try doing some math below! I'll start you off here,
15+4.4
# Out:
# 19.4

# %% [markdown]
# **Exercise**
#
# > Earlier, we stored my age. What will my age be in 5 more years?
#  **Calculate the answer by using `my_age` and a simple math operation**

# %%
# enter answer below

# %% [markdown]
# Mathematical operations are not limited to only numbers in Python. We can also add strings! For example:

# %%
print(my_name + ' is ' + str(my_age)  + ' years old.')
# Out:
# Suki is 77 years old.

# %% [markdown]
# ## Lists

# %% [markdown]
# Objectives:
# * understand that there are different types of variables
# * assign some variables
# * do basic math operations
#
# Syllabus:
# * learn to assign variables
# * learn about types of variables: strings, numbers
# * making and using lists
# * basic math calculations/operations
# * review best coding practices
#
# Ocean topic:
# * shark species and marine life around NYC (Jamaica Bay/Long Island)
#
# ```
# # This is formatted as code
# ```

# %%
# Out:
#   File "<ipython-input-1-d57d1a084bc9>", line 1
#     Now, here's my grocery list 🛒:
#                                   ^
# SyntaxError: EOL while scanning string literal
