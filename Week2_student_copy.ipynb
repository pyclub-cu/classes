# %% [markdown]
# <a href="https://colab.research.google.com/github/pyclub-cu/classes/blob/master/Week2_student_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Welcome to Google Colab!**

# %% [markdown]
# ## Learning Goals:
# * Familiarize ourselves with the notebook interface (Google Colab) (15 min)
# * Practice finding and `print`-ing ocean facts! (5 min)
# * Learn best coding practices

# %% [markdown]
# ## **Label your notebooks**

# %% [markdown]
# ## **How to `print`:**

# %%
#Fill in your name
print('<Your name>')
# Out:
# <Your name>

# %% [markdown]
# ![seahorse-hippocampus-hippocampus-full-width.jpg](data:image/jpeg;base64,...)

# %%
#This print statement prints seahorses' favorite food
print('<seahorse favorite food>')
# Out:
# <seahorse favorite food>

# %%
print("Hello, my name is Blue! I really love swimming with my babies in the Atlantic. Tourists love to catch me diving and hunting for krill. I'm really proud to be the largest animal ever.")
# Out:
# Hello, my name is Blue! I really love swimming with my babies in the Atlantic. Tourists love to catch me diving and hunting for krill. I'm really proud to be the largest animal ever.

# %% [markdown]
# ## **Best Coding Practices**

# %%
# This is a comment

# %% [markdown]
# - space between blocks of code
# - write comments
# - Indentation
# - label variables appropriately (e.g. if you have temperature data `temp = <data>`)
# - Don't let your code overflow
